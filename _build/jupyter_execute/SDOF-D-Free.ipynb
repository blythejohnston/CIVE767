# %% [markdown]
# ## SDOF Damped under Free Vibration

# %% [markdown]
# ### Import Necessary Packages and Functions

# %%
import numpy as np
from numpy import sqrt
from matplotlib import pyplot as plt

# %% [markdown]
# ### Set Variable Values for System

# %%
m = 50 #mass
k = 51.5 #stiffness
xi = 0.01 #damping ratio - use decimal not percentage
wn = sqrt(k/m)
c = xi*2*sqrt(m*k) # determine damping coef. from damping ratio
wd = wn*sqrt(1.0-xi**2.0)

# %% [markdown]
# ### Establish Initial Conditions

# %%
F0=0 #no forcing function in free vibration
x0=2 #initial displacement
v0=1 # initial velocity

# %% [markdown]
# ### Setup Sampling Protocol

# %%
T1=100 #duration of motion evaluation
deltaT=0.02 #time step
N=T1/deltaT #total number of time points
t=np.arange(0.0,T1,deltaT) #generate time vector
x = []
v = []
X = []
for ti in t:
  x = (np.exp(-xi*wn*ti))*((x0)*np.cos(wd*ti)+((v0+xi*wn*x0)/wd)*np.sin(wd*ti))
  X.append(x)

# %% [markdown]
# ### Plotting the Resulting Displacement Response

# %%
plt.plot(t,X)
plt.show()

# %%
print(X)
# Out:
# [2.0, 2.019582637854754, 2.038325457023373, 2.056221078156575, 2.0732624738629304, 2.0894429714606084, 2.1047562555819033, 2.1191963706295227, 2.1327577230836914, 2.145435083659178, 2.157223589311413, 2.168118745090945, 2.1781164258455163, 2.187212877769134, 2.1954047197975513, 2.2026889448496485, 2.209062920914268, 2.2145243919821125, 2.219071478822395, 2.2227026796039704, 2.225416870360768, 2.2272133053013894, 2.228091616962813, 2.228051816208197, 2.2270942920688532, 2.2252198114305166, 2.222429518564101, 2.218724934501201, 2.2141079562546606, 2.2085808558845845, 2.2021462794102558, 2.1948072455684464, 2.186567144418726, 2.177429735796371, 2.1673991476136028, 2.156479874009896, 2.1446767733521925, 2.1319950660858975, 2.1184403324376087, 2.104018509970585, 2.0887358909940126, 2.072599119827214, 2.055615189919958, 2.0377914408301465, 2.0191355550601546, 1.9996555547532002, 1.979359798251152, 1.9582569765152564, 1.936356109411313, 1.913666541860873, 1.8901979398601163, 1.865960286368091, 1.8409638770660626, 1.8152193159897725, 1.7887375110364627, 1.761529669348556, 1.7336072925759554, 1.704982172018954, 1.675666383653813, 1.6456722830430948, 1.6150125001329052, 1.5836999339392237, 1.551747747125563, 1.5191693604742278, 1.4859784472535056, 1.4521889274831357, 1.4178149621004739, 1.3828709470297877, 1.3473715071571686, 1.3113314902135795, 1.2747659605685924, 1.2376901